# %% [markdown]
# # Certamen – Desarrollo de Algoritmos en Python
#
# **Tiempo disponible:** 60 minutos &nbsp;|&nbsp; **Puntaje total:** 100 puntos
#
# ---
# > **Instrucciones:**
# > - Responde las preguntas teóricas **editando las celdas de texto** (doble clic para editar).
# > - Escribe el código en las **celdas de código** de cada ejercicio.
# > - Ejecuta cada celda con `Shift + Enter` para ver la salida de los ejercicios prácticos.
# > - Al terminar, guarda con `Ctrl + S` y sube el archivo al repositorio del classroom.
#
# ```
# # Abre la terminal integrada desde el menú "Terminal > Nueva Terminal" y ejecuta los siguientes comandos:
#
# git add certamen.ipynb
# git commit -m "Entrega certamen"
# git push origin main
#
# ```

# %% [markdown]
# ---
# ## Sección 1 – Preguntas teóricas (20 puntos)
#
# > Edita esta celda (doble clic) y escribe tus respuestas donde se indica.
#
# ---
# ### Pregunta 1 (4 pts)
# ¿Cuál es la diferencia entre `=` y `==` en Python? Entrega un ejemplo de cada uno.
#
# - **`=`** → *(Es para dar valores establecidos dentro de variables)*
# - **`==`** → *(Es un comparativo para identificar si ambas propuestas son iguales)*
# - Ejemplo `=` → `# Listado = 1`
# - Ejemplo `==` → `# if Listado == 10`
#
# ---
# ### Pregunta 2 (3 pts)
# ¿Qué imprime el siguiente código?
# ```python
# numeros = [10, 20, 30, 40, 50]
# print(numeros[0])
# print(numeros[-1])
# print(len(numeros))
# ```
# - Línea 1 imprime: El primer digito de la lista
# - Línea 2 imprime: El ultimo digito de la lista
# - Línea 3 imprime: Cuenta cuantos digitos hay en la lista
#
# ---
# ### Pregunta 3 (3 pts)
# ¿Qué tipo de dato devuelve siempre `input()`? ¿Por qué es importante saberlo al pedir números?
#
# *(Guarda el dato ingresado por el usuario para despues ser utilizado dentro del codigo, es importante saber pedirlo, porque sin este no hay ingreso de datos, aunque si son numeros se define antes del input la funcion int ya que si no tu numero sera ingresado como una funcion string)*
#
# ---
# ### Pregunta 4 (4 pts)
# Completa los resultados:
#
# | Expresión   | Resultado |
# |-------------|-----------|
# | `10 % 3`    |      7    |
# | `10 // 3`   |     3     |
# | `2 ** 4`    |     16    |
# | `15 % 5`    |     10    |
#
# ---
# ### Pregunta 5 (3 pts)
# ¿Cuándo usarías `for` y cuándo `while`? Da un ejemplo de situación para cada uno.
#
# - `for` → *(Para solicitar peticiones extra a algo que sea modificable, ej: Para listas o contabilicacion)*
# - `while` → *(Usaria para verificar variables de tipo int hasta que se cumplan condiciones, ej: Para dar tablas de multiplicacion)*
#
# ---
# ### Pregunta 6 (3 pts)
# ¿Qué hace cada método?
#
# | Método               | ¿Qué hace? |
# |----------------------|------------|
# | `lista.append(x)`    |Agrega algo a una lista|
# | `lista.remove(x)`    |elimina algo de una lista|
# | `len(lista)`         |Cuenta los datos de una lista|

# %% [markdown]
# ---
# ## Sección 2 – Análisis de código (20 puntos)
#
# > Lee cada bloque y escribe exactamente lo que se imprimiría. Edita esta celda con tus respuestas.
#
# ---
# ### Ejercicio 2.1 (5 pts)
# ```python
# nombre = "Carlos"
# edad = 20
# print(f"Hola, {nombre}. Tienes {edad} años.")
# print("Hola, " + nombre + ". Tienes " + str(edad) + " años.")
# ```
# **Salida:** *(Hola, Carlos. Tienes 20 años.
#             Hola, Carlos. Tienes 20 años.)*
#
# ---
# ### Ejercicio 2.2 (5 pts)
# ```python
# nota = 75
# if nota >= 90:
#     print("Aprobado con distinción")
# elif nota >= 60:
#     print("Aprobado")
# else:
#     print("Reprobado")
# ```
# **Salida:** *(Aprobado)*
#
# ---
# ### Ejercicio 2.3 (5 pts)
# ```python
# total = 0
# for i in range(1, 6):
#     total += i
# print(total)
# ```
# **Salida:** *(5)*
#
# ---
# ### Ejercicio 2.4 (5 pts)
# ```python
# frutas = ["manzana", "pera", "uva"]
# frutas.append("naranja")
# frutas.remove("pera")
# print(frutas)
# print(len(frutas))
# ```
# **Salida:** *(manzana, uva, naranja
#                 3)*

# %% [markdown]
# ---
# ## Sección 3 – Problemas de programación (60 puntos)
#
# ### Ejercicio 3.1 – Calculadora de propina (12 pts)
#
# Escribe un programa que:
# 1. Pida el **total de la cuenta** (puede ser decimal).
# 2. Pida el **porcentaje de propina** (número entero).
# 3. Calcule la **propina** y el **total a pagar**.
#
# **Salida esperada:**
# ```
# Ingresa el total de la cuenta: 8500
# Ingresa el porcentaje de propina (%): 10
# ----------------------------
# Propina: $850.0
# Total a pagar: $9350.0
# ```

# %%
# Ejercicio 3.1 – Calculadora de propina
# Escribe tu código aquí:
valor_cuenta_total = float(input("Ingresa el total de la cuenta: "))
propina_cuenta_total = int(input("Ingresa el porcentaje de propina (%): "))
valor_propina = valor_cuenta_total / propina_cuenta_total
print(f"Valor de la cuenta: {valor_cuenta_total}\nPropina: {valor_cuenta_total / propina_cuenta_total}\nTotal a pagar: {valor_propina + valor_cuenta_total}")
# Out:
# Valor de la cuenta: 1000.0
# Propina: 100.0
# Total a pagar: 1100.0

# %% [markdown]
# ---
# ### Ejercicio 3.2 – Clasificador de notas (16 pts)
#
# Escribe un programa que:
# 1. Pida una **nota entre 1.0 y 7.0**.
# 2. Valide el rango → si no es válida, muestra `"Nota inválida."` y termina.
# 3. Muestre el **concepto** y si está **aprobado o reprobado**.
#
# | Rango        | Concepto      |
# |--------------|---------------|
# | 6.0 – 7.0    | Excelente     |
# | 5.0 – 5.9    | Bueno         |
# | 4.0 – 4.9    | Suficiente    |
# | 1.0 – 3.9    | Insuficiente  |
#
# **Salida esperada:**
# ```
# Ingresa tu nota (1.0 - 7.0): 5.5
# Concepto: Bueno
# Estado: Aprobado
# ```

# %%
# Ejercicio 3.2 – Clasificador de notas
# Escribe tu código aquí:
notas = float(input("Ingrese una nota entre 1.0 y 7.0: "))
if notas > 7.0:
    print(f"Nota no valida")
elif notas >= 6.0:
    print(f"Excelente")
elif notas >= 5.0:
    print(f"Bueno")
elif notas >= 4.0:
    print(f"Suficiente")
elif notas >= 1.0:
    print(f"Insuficite")
else:
    print(f"Nota no valida")
# Out:
# Nota no valida

# %% [markdown]
# ---
# ### Ejercicio 3.3 – Gestión de lista de compras (16 pts)
#
# Usando la lista inicial `["leche", "pan", "huevos"]`:
# 1. Muestra la lista inicial.
# 2. Agrega `"mantequilla"` y `"jugo"`.
# 3. Elimina `"pan"`.
# 4. Muestra cuántos productos hay.
# 5. Recorre con `for` y muestra cada producto numerado desde 1.
#
# **Salida esperada:**
# ```
# Lista inicial: ['leche', 'pan', 'huevos']
# Lista actualizada: ['leche', 'huevos', 'mantequilla', 'jugo']
# Total de productos: 4
# 1. leche
# 2. huevos
# 3. mantequilla
# 4. jugo
# ```

# %%
# Ejercicio 3.3 – Gestión de lista de compras
# Escribe tu código aquí:
compras = ["leche", "pan", "huevos"]
print(compras)
compras.append("mantequilla")
compras.append("jugo")
print(compras)
compras.remove("pan")
print(len(compras))
for i in range(1,5):
    print(f"{i}. {compras}")
# Out:
# ['leche', 'pan', 'huevos']
# ['leche', 'pan', 'huevos', 'mantequilla', 'jugo']
# 4
# 1. ['leche', 'huevos', 'mantequilla', 'jugo']
# 2. ['leche', 'huevos', 'mantequilla', 'jugo']
# 3. ['leche', 'huevos', 'mantequilla', 'jugo']
# 4. ['leche', 'huevos', 'mantequilla', 'jugo']

# %% [markdown]
# ---
# ### Ejercicio 3.4 – Adivina el número (16 pts)
#
# - El número secreto es `secreto = 42` (fijo, **no lo pidas al usuario**).
# - Usa `while` para pedir intentos repetidamente.
# - En cada intento indica si el número es **mayor** o **menor**.
# - Al adivinar, muestra cuántos intentos necesitó.
#
# **Salida esperada:**
# ```
# Adivina el número secreto (entre 1 y 100):
# Intento 1: 50
# Es menor. Intenta de nuevo.
# Intento 2: 30
# Es mayor. Intenta de nuevo.
# Intento 3: 42
# ¡Correcto! Adivinaste en 3 intentos.
# ```

# %%
# Ejercicio 3.4 – Adivina el número
# Escribe tu código aquí:
secreto = 42
num_user = 0
num_user = int(input("Adivina el numero secreto entre 1 y 100: "))
while num_user > 0:
    if num_user == secreto:
        print(f"¡Correcto! Adivinaste.")
        break
    elif num_user <= secreto:
        print(f"Es menor. Intenta de nuevo.")
        pass
    elif num_user >= secreto:
        print(f"Es mayor. Intenta denuevo.")
        pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 14
#      10     elif num_user <= secreto:
#      11         print(f"Es menor. Intenta de nuevo.")
#      12         pass
#      13     elif num_user >= secreto:
# ---> 14         print(f"Es mayor. Intenta denuevo.")
#      15         pass
#
# File ~/.local/lib/python3.11/site-packages/ipykernel/iostream.py:747, in OutStream.write(self, string)
#     744     msg = "I/O operation on closed file"
#     745     raise ValueError(msg)
# --> 747 is_child = not self._is_master_process()
#     748 # only touch the buffer in the IO thread to avoid races
#     749 with self._buffer_lock:
#
# File ~/.local/lib/python3.11/site-packages/ipykernel/iostream.py:617, in OutStream._is_master_process(self)
#     616 def _is_master_process(self):
# --> 617     return os.getpid() == self._master_pid
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Tabla de puntajes
#
# | Sección                         | Puntaje máximo | Puntaje obtenido |
# |--------------------------------|----------------|------------------|
# | Sección 1 – Preguntas teóricas  | 20 pts         |                  |
# | Sección 2 – Análisis de código  | 20 pts         |                  |
# | Sección 3.1 – Calculadora       | 12 pts         |                  |
# | Sección 3.2 – Clasificador      | 16 pts         |                  |
# | Sección 3.3 – Lista de compras  | 16 pts         |                  |
# | Sección 3.4 – Adivina el número | 16 pts         |                  |
# | **Total**                       | **100 pts**    |                  |
#
# **Escala:** 51 pts o más → ✅ Aprobado &nbsp;|&nbsp; Menos de 51 pts → ❌ Reprobado
